# %%
# %matplotlib notebook

# %%
# import dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import scipy.stats as st
from scipy.stats import linregress

# %%
# open dataframe to work with
# file path
csv = 'Cleaned_Data/Final.csv'
#read csv
plot_df = pd.read_csv(csv)
plot_df.head()
# Out:
#         State  Confirmed Cases  COVID Deaths  Population Density  Population  \
# 0     Alabama           449086          7172             97.4270     4934190
# 1      Alaska            51603           250              1.2694      724357
# 2     Arizona           738561         12643             66.2016     7520100
# 3    Arkansas           288964          4742             58.3059     3033950
# 4  California          3169935         38224            254.2929    39613500
#
#    LandArea  Total Two Dose Regimen Moderna  Total Two Dose Regimen Pfizer  \
# 0     50645                          273100                         227175
# 1    570641                           84700                          62400
# 2    113594                          387100                         323700
# 3     52035                          165800                         141375
# 4    155779                         2178600                        1806675
#
#    Combined Total Doses
# 0                500275
# ...

# %%
#side by side plotting of dose distribution
doses = plot_df['Combined Total Doses']
cases = plot_df['Confirmed Cases']
deaths = plot_df['COVID Deaths']

plt.figure()
plt.subplot(1,2,1)
plt.scatter(doses, cases, figsize=(8,8))
plt.title('Doses v Confrimed Cases')

plt.show()
# Out:
# <div id='7e68446d-f228-4d77-97b2-2c8d3a7a5f79'></div>
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-23-072c9fe27390> in <module>
#       6 plt.figure()
#       7 plt.subplot(1,2,1)
# ----> 8 plt.scatter(doses, cases, figsize=(8,8))
#       9 plt.title('Doses v Confrimed Cases')
#      10
#
# ~\anaconda\anaconda3\envs\PythonData\lib\site-packages\matplotlib\pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, plotnonfinite, data, **kwargs)
#    2814         verts=verts, edgecolors=edgecolors,
#    2815         plotnonfinite=plotnonfinite, **({"data": data} if data is not
# -> 2816         None else {}), **kwargs)
#    2817     sci(__ret)
#    2818     return __ret
#
# ~\anaconda\anaconda3\envs\PythonData\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
# ...

# %%
doses =plot_df.iloc[:,8]
cases =plot_df.iloc[:,1]





plt.scatter(doses, cases)
plt.title('Doses vs Confrimed Cases')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5, 1.0, 'Doses vs Confrimed Cases')
