# %%
# %matplotlib notebook

# %%
# Import Dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
#Open All csv combined file to start manipulating for review
# open next CSV file for merge with cleaned file
All_CSV_Combined_csv = 'Cleaned_Data/All_CSV_Combined.csv'
# read csv
plotting_df = pd.read_csv(All_CSV_Combined_csv)
#view data
plotting_df.head()
# Out:
#         State  COVID-19 Deaths  Total Deaths  Pneumonia Deaths  \
# 0     Alabama             6195         62730              5069
# 1      Alaska              193          4721               270
# 2     Arizona             8498         77079              8720
# 3    Arkansas             3728         37869              3769
# 4  California            27622        315502             33784
#
#    Pneumonia and COVID-19 Deaths  Influenza Deaths  \
# 0                           2009               135
# 1                            109                 0
# 2                           4955               147
# 3                           1662               101
# 4                          15695               813
#
#    Pneumonia, Influenza, or COVID-19 Deaths   Density       Pop  LandArea  \
# 0                                      9381   97.4270   4934190     50645
# 1                                       363    1.2694    724357    570641
# ...

# %%
plotting_df.dtypes
# Out:
# State                                        object
# COVID-19 Deaths                              object
# Total Deaths                                 object
# Pneumonia Deaths                             object
# Pneumonia and COVID-19 Deaths                object
# Influenza Deaths                              int64
# Pneumonia, Influenza, or COVID-19 Deaths     object
# Density                                     float64
# Pop                                           int64
# LandArea                                      int64
# Total "Two Dose Regmine" Moderna             object
# Total "Two Dose Regmine" Pfizer              object
# Total Combined Doses                         object
# dtype: object

# %%
#combined_regmine['Moderna Pfizer Totals'] = plotting_df['Total "Two Dose Regmine" Moderna'] + plotting_df['Total "Two Dose Regmine" Pfizer']
#combined_regmine['x'] = plotting_df.iloc[:,10:11].sum()
plotting_df['Total Combined Doses'] = plotting_df[['Total "Two Dose Regimen" Moderna', 'Total "Two Dose Regimen" Pfizer']].sum(axis=1)



plotting_df.head()
# Out:
#         State  COVID-19 Deaths  Total Deaths  Pneumonia Deaths  \
# 0     Alabama             6195         62730              5069
# 1      Alaska              193          4721               270
# 2     Arizona             8498         77079              8720
# 3    Arkansas             3728         37869              3769
# 4  California            27622        315502             33784
#
#    Pneumonia and COVID-19 Deaths  Influenza Deaths  \
# 0                           2009               135
# 1                            109                 0
# 2                           4955               147
# 3                           1662               101
# 4                          15695               813
#
#    Pneumonia, Influenza, or COVID-19 Deaths   Density       Pop  LandArea  \
# 0                                      9381   97.4270   4934190     50645
# 1                                       363    1.2694    724357    570641
# ...
