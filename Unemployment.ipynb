# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st

# Display the data table for preview
unemployment_data_us_state_path = "unemployment_data_us_state.csv"
Population_Density_path = "Population_Density.csv"
Provisional_COVID_19_Death_Counts_by_Sex__Age__and_State_path = "Provisional_COVID_19_Death_Counts_by_Sex__Age__and_State.csv"

# Read the mouse data and the study results
unemployment_data_us_state = pd.read_csv(unemployment_data_us_state_path)
Population_Density = pd.read_csv(Population_Density_path)
Provisional_COVID_19_Death_Counts_by_Sex__Age__and_State = pd.read_csv(Provisional_COVID_19_Death_Counts_by_Sex__Age__and_State_path)

# Combine the data into a single dataset
merge_data_df = pd.merge(unemployment_data_us_state, Population_Density, on="State")
# Display the data table for preview
merge_data_df
# Out:
#              State  rate  rate.1  Change  Rank    Density       Pop  LandArea
# 0          Alabama   5.7     4.4    -1.3     5    97.4270   4934190     50645
# 1           Alaska   5.9     8.1     2.2    50     1.2694    724357    570641
# 2          Arizona   7.9     7.8    -0.1    32    66.2016   7520100    113594
# 3         Arkansas   6.2     6.2     0.0    36    58.3059   3033950     52035
# 4       California   9.0     8.2    -0.8    10   254.2929  39613500    155779
# 5         Colorado   6.4     6.4     0.0    36    56.8653   5893630    103642
# 6      Connecticut   6.1     8.2     2.1    49   733.7505   3552820      4842
# 7         Delaware   5.6     5.1    -0.5    18   508.1242    990334      1949
# 8          Florida   6.4     6.4     0.0    36   409.2233  21944600     53625
# 9          Georgia   4.5     5.7     1.2    47   188.3053  10830000     57513
# 10          Hawaii  14.2    10.1    -4.1     1   218.9678   1406430      6423
# ...

# %%
# clean the data into a dataset
main_data_df2 = Provisional_COVID_19_Death_Counts_by_Sex__Age__and_State.loc[:, ['State', 'COVID-19 Deaths']]

# Display the data table for preview
main_data_df2
# Out:
#               State COVID-19 Deaths
# 0     United States         347,131
# 1     United States              39
# 2     United States             165
# 3     United States              21
# 4     United States              58
# ...             ...             ...
# 2656    Puerto Rico               0
# 2657    Puerto Rico               0
# 2658    Puerto Rico               0
# 2659    Puerto Rico               0
# 2660    Puerto Rico               0
#
# [2661 rows x 2 columns]

# %%
#count totals per state
state_count = main_data_df2['State'].count()

#setup dataframe
summary_state_df = pd.DataFrame({'Total Count': state_count})

#print dataframe results
summary_state_df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-23-3e26d187e7a1> in <module>
#       3
#       4 #setup dataframe
# ----> 5 summary_state_df = pd.DataFrame({'Total Count': state_count})
#       6
#       7 #print dataframe results
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     433             )
#     434         elif isinstance(data, dict):
# --> 435             mgr = init_dict(data, index, columns, dtype=dtype)
#     436         elif isinstance(data, ma.MaskedArray):
#     437             import numpy.ma.mrecords as mrecords
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\internals\construction.py in init_dict(data, index, columns, dtype)
#     252             arr if not is_datetime64tz_dtype(arr) else arr.copy() for arr in arrays
#     253         ]
# ...
